# %%
# data manipulation libraries
import pandas as pd
import numpy as np
import copy
import os

# imports visualisation libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# tensorflow and keras imports
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.applications.efficientnet import preprocess_input # as efficientnet_preprocess_input
import datetime
import os

# trying to suppress warnings
tf.get_logger().setLevel('ERROR')

# Suppress annoying warnings
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR) # supress tensorflow warnings

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# take this off if using GPU
# Ensure no GPUs are visible to TensorFlow
# tf.config.set_visible_devices([], 'GPU')  # Disable GPU
# tf.config.experimental.set_visible_devices([], 'GPU')

# evaluation
from sklearn.metrics import confusion_matrix,  f1_score, accuracy_score
# Out:
# 2025-02-05 12:08:24.384766: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738757305.060297   28027 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738757305.252829   28027 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-05 12:08:27.145423: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Functions for evaluation
#
# A lot of this was from NN coursework

# %%
# The code for the charts is based on code from pp74-75 from Deep Learning with Python [8].
# function to create charts for training and validation loss/accuracy
# based on code from p75 DLWP
def loss_accuracy_charts(hist):
    # gets loss/accuracy data from history object
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    accuracy = hist.history['accuracy']
    val_accuracy = hist.history['val_accuracy']

    epochs = range(1, len(loss) + 1) # this gets numbers of epochs to use in plotting (on the x axis)

    plt.figure(figsize=(12, 5))

    # plot training/validation loss
    plt.subplot(1, 2, 1)  # plots in col 1
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # plot training/validation accuracy
    plt.subplot(1, 2, 2)  # plots in col 2
    plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
    plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
#### function to get y_true and y_pred

def get_y_vals(current_model, test_dataset):
    y_true = []
    y_pred = []
    
    for images, labels in test_dataset:
        # append true labels
        y_true.extend(labels.numpy())
        
        # get predictions
        predictions = current_model.predict(images) # https://keras.io/api/models/model_training_apis/
        
        # convert preds back to class labels
        y_pred.extend(np.argmax(predictions, axis=1))
    
    # convert y_true to a flat list
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    return y_true, y_pred

# %%
#### function for evaluation of results, gets loss, accuracy from results and calculates F1
def model_results(res, y_true, y_pred):
    print(f"Loss:{res[0]}")
    print(f"Accuracy:{res[1]}")
    print(f"F1 (macro): {f1_score(y_true, y_pred, average='macro')}")
    print(f"F1 (weighted): {f1_score(y_true, y_pred, average='weighted')}")

# %%
# function for confusion matrix

def conf_mat_func(y_true,y_pred):
    conf_matrix = confusion_matrix(y_true, y_pred) # create confusion matrix data
    # plot the confusion matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.title('Confusion Matrix')
    plt.show()

# %%
# brings all functions together to evaluate

def evaluation(current_model,test_dataset,res, history):
    y_true, y_pred = get_y_vals(current_model,test_dataset)
    
    model_results(res,y_true,y_pred)
    
    loss_accuracy_charts(history)
    
    conf_mat_func(y_true,y_pred)

# %% [markdown]
# # Model Training

# %% [markdown]
# # EfficientNet_v2
#
# Added L2

# %%
# function to load and preprocess
def import_data(image_size, batch_size, base_dir, colour):
    # Load the full dataset with a 80-20 split
    full_val_test_ds = tf.keras.utils.image_dataset_from_directory(
        base_dir,
        validation_split=0.2,
        subset='validation',
        seed=321,
        shuffle=True,
        image_size=image_size,
        batch_size=batch_size,
        color_mode = colour
    )
    
    # further split (10%) and test (10%)
    val_size = int(0.5 * tf.data.experimental.cardinality(full_val_test_ds).numpy())
    val_ds = full_val_test_ds.take(val_size)
    test_ds = full_val_test_ds.skip(val_size)
    
    # training set (80%)
    train_ds = tf.keras.utils.image_dataset_from_directory(
        base_dir,
        validation_split=0.2,
        subset='training',
        seed=321,
        shuffle=True,
        image_size=image_size,
        batch_size=batch_size,
        color_mode = colour
    )


    class_names = train_ds.class_names


    # data augmentation pipeline
    data_augmentation = tf.keras.Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2, fill_mode='nearest'),
        layers.RandomBrightness(0.2),
        layers.RandomContrast(0.2),
        layers.RandomTranslation(0.1, 0.1, fill_mode='nearest'),
        layers.GaussianNoise(0.1)
    ])

    # https://www.tensorflow.org/guide/data_performance
    AUTOTUNE = tf.data.AUTOTUNE

    # training set pipeline

    train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))
    train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y))  # Normalize for ResNet50

    train_ds = train_ds.cache().shuffle(buffer_size=tf.data.experimental.cardinality(train_ds).numpy()).prefetch(buffer_size=AUTOTUNE)
    

    # test and val dataset pipleine
    val_ds = val_ds.map(lambda x, y: (preprocess_input(x), y))
    test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y))
    val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
    test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

    return train_ds, val_ds, test_ds


# directory and image configurations
base_dir = r'/home/azureuser/cloudfiles/code/Users/richesmith/Eurosat_RGB'
image_size = (224, 224)
batch_size = 64
colour = 'rgb'
train_ds, val_ds, test_ds = import_data(image_size, batch_size, base_dir, colour)


# defines the efficient net model
efficientnet_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
efficientnet_model.trainable = False


# model architecture

model = models.Sequential([
    efficientnet_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(1e-5)),  # added L2 regularisation
    layers.Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(1e-5))  # L2 here too
])

# learning rate
optimizer = Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# callbacks for early stopping and model checkpointing
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('efficientnet_model_v2_best_L21e5_LR1e5_8020split.keras', save_best_only=True)

# trains model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,  # increased epochs to 50
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Found 27000 files belonging to 10 classes.
# Using 5400 files for validation.
# Found 27000 files belonging to 10 classes.
# Using 21600 files for training.
# Epoch 1/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 321s 105ms/step - accuracy: 0.2209 - loss: 2.3773 - val_accuracy: 0.6607 - val_loss: 1.2523
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.6455 - loss: 1.0864 - val_accuracy: 0.7906 - val_loss: 0.6954
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.7426 - loss: 0.8116 - val_accuracy: 0.8385 - val_loss: 0.5360
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.7789 - loss: 0.6796 - val_accuracy: 0.8616 - val_loss: 0.4513
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.8029 - loss: 0.6067 - val_accuracy: 0.8772 - val_loss: 0.4017
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8208 - loss: 0.5518 - val_accuracy: 0.8873 - val_loss: 0.3656
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.8414 - loss: 0.5026 - val_accuracy: 0.8899 - val_loss: 0.3386
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.8489 - loss: 0.4639 - val_accuracy: 0.8962 - val_loss: 0.3191
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8564 - loss: 0.4342 - val_accuracy: 0.9033 - val_loss: 0.3058
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8614 - loss: 0.4280 - val_accuracy: 0.9077 - val_loss: 0.2912
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8677 - loss: 0.4076 - val_accuracy: 0.9118 - val_loss: 0.2808
# Epoch 12/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.8709 - loss: 0.3938 - val_accuracy: 0.9144 - val_loss: 0.2738
# Epoch 13/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8727 - loss: 0.3865 - val_accuracy: 0.9163 - val_loss: 0.2628
# Epoch 14/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8758 - loss: 0.3707 - val_accuracy: 0.9182 - val_loss: 0.2554
# Epoch 15/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8809 - loss: 0.3573 - val_accuracy: 0.9219 - val_loss: 0.2471
# Epoch 16/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8852 - loss: 0.3468 - val_accuracy: 0.9234 - val_loss: 0.2421
# Epoch 17/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.8900 - loss: 0.3368 - val_accuracy: 0.9249 - val_loss: 0.2377
# Epoch 18/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.8918 - loss: 0.3299 - val_accuracy: 0.9252 - val_loss: 0.2329
# Epoch 19/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8940 - loss: 0.3219 - val_accuracy: 0.9260 - val_loss: 0.2299
# Epoch 20/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8956 - loss: 0.3142 - val_accuracy: 0.9267 - val_loss: 0.2275
# Epoch 21/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.8984 - loss: 0.3109 - val_accuracy: 0.9301 - val_loss: 0.2241
# Epoch 22/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.8963 - loss: 0.3093 - val_accuracy: 0.9301 - val_loss: 0.2220
# Epoch 23/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9015 - loss: 0.2980 - val_accuracy: 0.9297 - val_loss: 0.2167
# Epoch 24/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9033 - loss: 0.2965 - val_accuracy: 0.9308 - val_loss: 0.2132
# Epoch 25/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9053 - loss: 0.2892 - val_accuracy: 0.9319 - val_loss: 0.2129
# Epoch 26/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.9119 - loss: 0.2767 - val_accuracy: 0.9334 - val_loss: 0.2108
# Epoch 27/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9120 - loss: 0.2747 - val_accuracy: 0.9342 - val_loss: 0.2105
# Epoch 28/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9087 - loss: 0.2756 - val_accuracy: 0.9349 - val_loss: 0.2058
# Epoch 29/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9148 - loss: 0.2665 - val_accuracy: 0.9345 - val_loss: 0.2050
# Epoch 30/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9159 - loss: 0.2620 - val_accuracy: 0.9349 - val_loss: 0.2018
# Epoch 31/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9151 - loss: 0.2614 - val_accuracy: 0.9349 - val_loss: 0.2020
# Epoch 32/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9145 - loss: 0.2584 - val_accuracy: 0.9338 - val_loss: 0.1995
# Epoch 33/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9225 - loss: 0.2487 - val_accuracy: 0.9345 - val_loss: 0.1992
# Epoch 34/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9199 - loss: 0.2482 - val_accuracy: 0.9342 - val_loss: 0.1974
# Epoch 35/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9252 - loss: 0.2423 - val_accuracy: 0.9330 - val_loss: 0.1973
# Epoch 36/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9215 - loss: 0.2436 - val_accuracy: 0.9353 - val_loss: 0.1926
# Epoch 37/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9244 - loss: 0.2364 - val_accuracy: 0.9356 - val_loss: 0.1953
# Epoch 38/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9243 - loss: 0.2363 - val_accuracy: 0.9345 - val_loss: 0.1916
# Epoch 39/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9253 - loss: 0.2360 - val_accuracy: 0.9379 - val_loss: 0.1911
# Epoch 40/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.9270 - loss: 0.2316 - val_accuracy: 0.9345 - val_loss: 0.1905
# Epoch 41/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9275 - loss: 0.2322 - val_accuracy: 0.9375 - val_loss: 0.1889
# Epoch 42/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9266 - loss: 0.2258 - val_accuracy: 0.9356 - val_loss: 0.1901
# Epoch 43/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9286 - loss: 0.2233 - val_accuracy: 0.9386 - val_loss: 0.1879
# Epoch 44/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9316 - loss: 0.2183 - val_accuracy: 0.9375 - val_loss: 0.1864
# Epoch 45/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9301 - loss: 0.2212 - val_accuracy: 0.9382 - val_loss: 0.1863
# Epoch 46/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9325 - loss: 0.2178 - val_accuracy: 0.9382 - val_loss: 0.1887
# Epoch 47/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9337 - loss: 0.2092 - val_accuracy: 0.9397 - val_loss: 0.1847
# Epoch 48/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9343 - loss: 0.2079 - val_accuracy: 0.9416 - val_loss: 0.1835
# Epoch 49/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9374 - loss: 0.2057 - val_accuracy: 0.9401 - val_loss: 0.1850
# Epoch 50/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9401 - loss: 0.1960 - val_accuracy: 0.9405 - val_loss: 0.1843
# I0000 00:00:1738757317.606551   28027 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14793 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0001:00:00.0, compute capability: 7.5
# 2025-02-05 12:09:00.984770: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 13 of 338
# 2025-02-05 12:09:20.579996: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 38 of 338
# 2025-02-05 12:09:30.788205: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 51 of 338
# 2025-02-05 12:09:40.996421: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 64 of 338
# 2025-02-05 12:10:00.606263: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 89 of 338
# 2025-02-05 12:10:10.798838: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 102 of 338
# 2025-02-05 12:10:20.972265: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 115 of 338
# 2025-02-05 12:10:40.573009: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 140 of 338
# 2025-02-05 12:10:50.776243: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 153 of 338
# 2025-02-05 12:11:00.985173: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 166 of 338
# 2025-02-05 12:11:20.602112: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 191 of 338
# 2025-02-05 12:11:30.804531: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 204 of 338
# 2025-02-05 12:11:41.036896: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 217 of 338
# 2025-02-05 12:12:00.645195: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 242 of 338
# 2025-02-05 12:12:10.842988: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 255 of 338
# 2025-02-05 12:12:21.042761: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 268 of 338
# 2025-02-05 12:12:40.668391: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 293 of 338
# 2025-02-05 12:12:50.861277: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 306 of 338
# 2025-02-05 12:13:01.044252: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:19: Filling up shuffle buffer (this may take a while): 319 of 338
# 2025-02-05 12:13:15.533236: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738757595.539951   28195 service.cc:148] XLA service 0x7f4420001980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738757595.544312   28195 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2025-02-05 12:13:15.910439: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1738757597.234583   28195 cuda_dnn.cc:529] Loaded cuDNN version 90500

# %%
# # evaluates on the test set
results = model.evaluate(test_ds)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.9301 - loss: 0.2021

# %%
# get test results
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Test Loss: 0.20255398750305176, Test Accuracy: 0.9332596063613892

# %%
# get evaluation
evaluation(model,test_ds,results,history)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 2025-02-05 12:31:02.408560: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # EfficientNet_v3
#
# Added L2
#
# Added LR decay

# %%
# function to load and preprocess
def import_data(image_size, batch_size, base_dir, colour):
    # load with 80-20 split
    full_val_test_ds = tf.keras.utils.image_dataset_from_directory(
        base_dir,
        validation_split=0.2,
        subset='validation',
        seed=321,
        shuffle=True,
        image_size=image_size,
        batch_size=batch_size,
        color_mode = colour
    )
    
    # further split (10%) and test (10%)
    val_size = int(0.5 * tf.data.experimental.cardinality(full_val_test_ds).numpy())
    val_ds = full_val_test_ds.take(val_size)
    test_ds = full_val_test_ds.skip(val_size)
    
    # training set (80%)
    train_ds = tf.keras.utils.image_dataset_from_directory(
        base_dir,
        validation_split=0.2,
        subset='training',
        seed=321,
        shuffle=True,
        image_size=image_size,
        batch_size=batch_size,
        color_mode = colour
    )


    class_names = train_ds.class_names


    # data augmentation pipeline
    data_augmentation = tf.keras.Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2, fill_mode='nearest'),
        layers.RandomBrightness(0.2),
        layers.RandomContrast(0.2),
        layers.RandomTranslation(0.1, 0.1, fill_mode='nearest'),
        layers.GaussianNoise(0.1)
    ])

    # https://www.tensorflow.org/guide/data_performance
    AUTOTUNE = tf.data.AUTOTUNE

    # training set pipeline
    train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))
    train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y))  # normalise for efficientnet
    # sets shuffle size dynamically to be same size as the dataset
    train_ds = train_ds.cache().shuffle(buffer_size=tf.data.experimental.cardinality(train_ds).numpy()).prefetch(buffer_size=AUTOTUNE)
    

    # test and val dataset pipleine
    val_ds = val_ds.map(lambda x, y: (preprocess_input(x), y))
    test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y))
    val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
    test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

    return train_ds, val_ds, test_ds


# directory and image configurations
base_dir = r'/home/azureuser/cloudfiles/code/Users/richesmith/Eurosat_RGB'
image_size = (224, 224)
batch_size = 64
colour = 'rgb'
train_ds, val_ds, test_ds = import_data(image_size, batch_size, base_dir, colour)


# defines the efficientnet model
efficientnet_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
efficientnet_model.trainable = False


# model architecture

# decreased L2 slightly
model = models.Sequential([
    efficientnet_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(1e-6)),  # added L2 regularisation
    layers.Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(1e-6))  # L2 here too
])

# Adam default is 0.001
# added learning rate decay
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-4, decay_steps=1000, decay_rate=0.96
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# callbacks for early stopping and model checkpointing
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('efficientnet_model_v3_best_L21e6_LRDecay_8020split_pat10.keras', save_best_only=True)

# train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Found 27000 files belonging to 10 classes.
# Using 5400 files for validation.
# Found 27000 files belonging to 10 classes.
# Using 21600 files for training.
# Epoch 1/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 313s 94ms/step - accuracy: 0.6353 - loss: 1.1468 - val_accuracy: 0.8984 - val_loss: 0.3990
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.8667 - loss: 0.4104 - val_accuracy: 0.9237 - val_loss: 0.2416
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.8918 - loss: 0.3304 - val_accuracy: 0.9230 - val_loss: 0.2202
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9123 - loss: 0.2700 - val_accuracy: 0.9342 - val_loss: 0.1963
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9164 - loss: 0.2560 - val_accuracy: 0.9323 - val_loss: 0.1926
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9268 - loss: 0.2238 - val_accuracy: 0.9386 - val_loss: 0.1796
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9348 - loss: 0.2100 - val_accuracy: 0.9390 - val_loss: 0.1820
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9365 - loss: 0.1988 - val_accuracy: 0.9449 - val_loss: 0.1691
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9375 - loss: 0.1832 - val_accuracy: 0.9420 - val_loss: 0.1745
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9466 - loss: 0.1701 - val_accuracy: 0.9427 - val_loss: 0.1724
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9500 - loss: 0.1613 - val_accuracy: 0.9405 - val_loss: 0.1710
# Epoch 12/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9528 - loss: 0.1586 - val_accuracy: 0.9449 - val_loss: 0.1653
# Epoch 13/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.9539 - loss: 0.1517 - val_accuracy: 0.9442 - val_loss: 0.1651
# Epoch 14/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9570 - loss: 0.1419 - val_accuracy: 0.9449 - val_loss: 0.1633
# Epoch 15/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.9592 - loss: 0.1342 - val_accuracy: 0.9483 - val_loss: 0.1578
# Epoch 16/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9622 - loss: 0.1250 - val_accuracy: 0.9438 - val_loss: 0.1628
# Epoch 17/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9631 - loss: 0.1257 - val_accuracy: 0.9408 - val_loss: 0.1722
# Epoch 18/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9611 - loss: 0.1256 - val_accuracy: 0.9449 - val_loss: 0.1656
# Epoch 19/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9654 - loss: 0.1195 - val_accuracy: 0.9427 - val_loss: 0.1629
# Epoch 20/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.9697 - loss: 0.1083 - val_accuracy: 0.9487 - val_loss: 0.1568
# Epoch 21/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9694 - loss: 0.1077 - val_accuracy: 0.9438 - val_loss: 0.1631
# Epoch 22/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9725 - loss: 0.1005 - val_accuracy: 0.9412 - val_loss: 0.1645
# Epoch 23/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9685 - loss: 0.1035 - val_accuracy: 0.9475 - val_loss: 0.1594
# Epoch 24/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9732 - loss: 0.0973 - val_accuracy: 0.9420 - val_loss: 0.1663
# Epoch 25/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9720 - loss: 0.0964 - val_accuracy: 0.9435 - val_loss: 0.1685
# Epoch 26/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9718 - loss: 0.0964 - val_accuracy: 0.9472 - val_loss: 0.1610
# Epoch 27/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9730 - loss: 0.0900 - val_accuracy: 0.9442 - val_loss: 0.1657
# Epoch 28/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9751 - loss: 0.0918 - val_accuracy: 0.9487 - val_loss: 0.1575
# Epoch 29/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9745 - loss: 0.0862 - val_accuracy: 0.9487 - val_loss: 0.1536
# Epoch 30/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9739 - loss: 0.0849 - val_accuracy: 0.9457 - val_loss: 0.1602
# Epoch 31/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9738 - loss: 0.0857 - val_accuracy: 0.9449 - val_loss: 0.1631
# Epoch 32/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9792 - loss: 0.0806 - val_accuracy: 0.9453 - val_loss: 0.1674
# Epoch 33/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9782 - loss: 0.0791 - val_accuracy: 0.9438 - val_loss: 0.1669
# Epoch 34/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9769 - loss: 0.0793 - val_accuracy: 0.9453 - val_loss: 0.1629
# Epoch 35/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9778 - loss: 0.0758 - val_accuracy: 0.9457 - val_loss: 0.1624
# Epoch 36/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9771 - loss: 0.0784 - val_accuracy: 0.9442 - val_loss: 0.1689
# Epoch 37/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9799 - loss: 0.0734 - val_accuracy: 0.9390 - val_loss: 0.1735
# Epoch 38/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9793 - loss: 0.0722 - val_accuracy: 0.9483 - val_loss: 0.1591
# Epoch 39/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9791 - loss: 0.0727 - val_accuracy: 0.9505 - val_loss: 0.1573
# 2025-02-05 12:31:24.190467: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 13 of 338
# 2025-02-05 12:31:34.435108: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 26 of 338
# 2025-02-05 12:31:54.133833: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 51 of 338
# 2025-02-05 12:32:04.369744: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 64 of 338
# 2025-02-05 12:32:24.139545: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 89 of 338
# 2025-02-05 12:32:34.394549: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 102 of 338
# 2025-02-05 12:32:54.116598: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 127 of 338
# 2025-02-05 12:33:04.358576: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 140 of 338
# 2025-02-05 12:33:24.036552: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 165 of 338
# 2025-02-05 12:33:34.298868: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 178 of 338
# 2025-02-05 12:33:54.006320: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 203 of 338
# 2025-02-05 12:34:04.280107: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 216 of 338
# 2025-02-05 12:34:24.018870: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 241 of 338
# 2025-02-05 12:34:34.267597: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 254 of 338
# 2025-02-05 12:34:53.981346: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 279 of 338
# 2025-02-05 12:35:04.275657: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 292 of 338
# 2025-02-05 12:35:23.987948: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 317 of 338
# 2025-02-05 12:35:34.262394: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:610: Filling up shuffle buffer (this may take a while): 330 of 338
# 2025-02-05 12:35:40.161213: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.

# %%
# # evaluate on the test set
results = model.evaluate(test_ds)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 144ms/step - accuracy: 0.9467 - loss: 0.1580

# %%
# get test results
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Test Loss: 0.17428314685821533, Test Accuracy: 0.9421091675758362

# %%
# get evaluation
evaluation(model,test_ds,results,history)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 2025-02-05 12:49:18.075040: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
